# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Ramya Varahagiri__
#
# Software Engineer

# %% [markdown]
# _I am interested in Data Science because I love to see the how the world is emerging with how we can manipulate and interpret data. There's so many possibilities and oppportunities and Data Science is the foundation to many more advances the future will go through_

# %% [markdown]
# ### My Code is going to print Hello world

# %%
print ("Hello, World")

# %% [markdown]
# __*WAIT FOR IT*__
#
# ![image.png](attachment:image.png)
# ***
# * Why should you take a data scientist with you into the jungle? Answer: They can take care of Python problems
# * The data science motto: If at first, you don’t succeed; call it version 1.0
# * I have a machine learning joke, but I cannot explain it
#  1.  ~~Here are more funny one's. Hopefully that can make you laugh~~
#  2.  Never Mind, positng the link below :)
# * https://datasciencedojo.com/blog/data-science-memes/
#
#  >                                       HAPPY LEARNING
